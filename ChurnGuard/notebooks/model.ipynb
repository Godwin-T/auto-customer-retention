# %%
import mlflow
import pandas as pd
from matplotlib import pyplot as plt

from hyperopt.pyll import scope
from hyperopt import hp, STATUS_OK, fmin, Trials, tpe

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

import xgboost as xgb
from sklearn.pipeline import make_pipeline

from sklearn.metrics import (precision_score, recall_score,
                             f1_score, accuracy_score)

import warnings
warnings.filterwarnings('ignore')

# %%
mlflow.set_tracking_uri('sqlite:///../../databases/mlflow.db')
mlflow.set_experiment('Customer_Churn_Predictions')
# Out:
# <Experiment: artifact_location='/home/godwin/Documents/Workflow/Customer-retention/ChurnGuard/notebooks/mlruns/1', creation_time=1719532937208, experiment_id='1', last_update_time=1719532937208, lifecycle_stage='active', name='Customer_Churn_Predictions', tags={}>

# %%
path = '../../data/churn-data/data/processed_data/churn.csv'
data = pd.read_csv(path)

y = data['churn']
X = data.drop(['churn'], axis=1)
X = X.to_dict(orient="record")


(train_x, test_x, 
    train_y, test_y) = train_test_split(X, y, test_size= 0.3, random_state=1993)

# %%
def evaluate_model(y_true, y_pred):

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1score = f1_score(y_true, y_pred)

    out = {"accuracy_score" : accuracy, 
            "precision_score" :precision, 
            "recall_score" : recall, 
            "f1_score" : f1score}
    return out

# %%
# Linear Model
c_values = range(1, 50, 5)
for val in c_values:

    with mlflow.start_run():
        mlflow.set_tag('Developer', 'Godwin')
        mlflow.set_tag('model', 'Logistic Regression')
        mlflow.log_param('C', val)

        lr_pipeline = make_pipeline(DictVectorizer(sparse= False),
                                    LogisticRegression(C =val))
        lr_pipeline.fit(train_x, train_y)

        test_pred = lr_pipeline.predict(test_x)
        test_output_eval = evaluate_model(test_y, test_pred)
        mlflow.log_metrics(test_output_eval)
        # mlflow.sklearn.log_model(lr_pipeline, artifact_path="models_mlflow")

# %%
def objective(params):

    with mlflow.start_run():
        mlflow.set_tag('Developer', 'Godwin')
        mlflow.set_tag('model', 'DecisionTree')
        mlflow.log_params(params)

        pipeline = make_pipeline(DictVectorizer(sparse=False),
                                DecisionTreeClassifier(**params))
        pipeline.fit(train_x, train_y)

        prediction = pipeline.predict(test_x)
        prediction_eval = evaluate_model(test_y, prediction)   
        
        mlflow.log_metrics(prediction_eval)
        # mlflow.sklearn.log_model(pipeline, artifact_path="models_mlflow")
        
    return {"loss": -prediction_eval['f1_score'], 'status': STATUS_OK}

space = {"max_depth": hp.randint("max_depth", 1, 15),
        'min_samples_split': hp.randint("min_samples_split", 2, 15),
        'min_samples_leaf': hp.randint("min_samples_leaf", 1, 15),
        "criterion": hp.choice("criterion", ["gini", "entropy"]),
        }

best_result = fmin(fn= objective,
                    space=space,
                    algo=tpe.suggest,
                    max_evals=50,
                    trials=Trials()
                    )
# Out:
# 100%|██████████| 50/50 [00:11<00:00,  4.28trial/s, best loss: -0.6195165622202327]

# %%
def random_forest_objective(params):

    with mlflow.start_run():
        mlflow.set_tag('Developer', 'Godwin')
        mlflow.set_tag('model', 'RandonForest')
        mlflow.log_params(params)

        pipeline = make_pipeline(DictVectorizer(sparse=False),
                                RandomForestClassifier(**params))
        pipeline.fit(train_x, train_y)

        prediction = pipeline.predict(test_x)
        prediction_eval = evaluate_model(test_y, prediction) 

        mlflow.log_metrics(prediction_eval)
        # mlflow.sklearn.log_model(pipeline, artifact_path="models_mlflow")
        
    return {"loss": -prediction_eval['f1_score'], 'status': STATUS_OK}


space = {"n_estimators": hp.choice("n_estimators", [2,5,10, 20, 30, 50, 100,]),
            'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 5)),
            #'min_samples_split': hp.randint("min_samples_split", 2, 15),
           # 'min_samples_leaf': hp.randint("min_samples_leaf", 1, 15),
            "criterion": hp.choice("criterion", ["gini", "entropy"]),
            }

best_result = fmin(fn=random_forest_objective,
                    space=space,
                    algo=tpe.suggest,
                    max_evals=50,
                    trials=Trials())
# Out:
# 100%|██████████| 50/50 [00:24<00:00,  2.05trial/s, best loss: -0.591715976331361]

# %%
class XGBoostTrainer():
    def __init__(self, params, num_boost_round=1000, early_stopping_rounds=50):
        self.params = params
        self.num_boost_round = num_boost_round
        self.early_stopping_rounds = early_stopping_rounds
        self.booster = None
        self.dict_vectorizer = DictVectorizer(sparse=False)

    def fit(self, X, y):
        # Assuming X, y are your training data and labels
        # Convert the input features to a sparse matrix using DictVectorizer
        
        X_sparse = self.dict_vectorizer.fit_transform(X)

        # Create xgb.DMatrix
        dtrain = xgb.DMatrix(X_sparse, label=y)

        # Train the XGBoost model
        self.booster = xgb.train(self.params,
                                 dtrain=dtrain,
                                 num_boost_round=self.num_boost_round,
                                 early_stopping_rounds=self.early_stopping_rounds,
                                 evals=[(dtrain, 'train')],
                                 verbose_eval=50)
        # mlflow.xgboost.log_model(self.booster, artifact_path='models_mlflow')

        return self

    def predict(self, X):
        # Convert the input features to a sparse matrix using DictVectorizer
        X_sparse = self.dict_vectorizer.transform(X)

        # Create xgb.DMatrix
        dmatrix = xgb.DMatrix(X_sparse)

        # Use the trained model for predictions
        predictions = self.booster.predict(dmatrix)
        return predictions

# %%
def objective(params):

    with mlflow.start_run():

        mlflow.set_tag('Developer', 'Godwin')
        mlflow.set_tag("model", "Xgboost")
        
        mlflow.log_params(params)
        
        booster =  make_pipeline(XGBoostTrainer(params = params))
        
        booster.fit(train_x, train_y)
        prediction = booster.predict(test_x)
        prediction = (prediction >= 0.5).astype('int')
        
        prediction_eval = evaluate_model(test_y, prediction)  
        mlflow.log_metrics(prediction_eval)
        

    return {'loss': -prediction_eval['f1_score'], 'status': STATUS_OK}

search_space = {
            'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 3)),
            'learning_rate': hp.loguniform('learning_rate', -3, 0),
            'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
            'objective': 'binary:logistic',  
            'eval_metric': 'logloss',                                             
            'seed': 42
                }

best_result = fmin(
                fn= objective,
                space=search_space,
                algo=tpe.suggest,
                max_evals=50,
                trials=Trials()
                )
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# [0]	train-logloss:0.55770
# [50]	train-logloss:0.26355
# [100]	train-logloss:0.20673
# [150]	train-logloss:0.18073
# [200]	train-logloss:0.15936
# [250]	train-logloss:0.14232
# [300]	train-logloss:0.12862
# [350]	train-logloss:0.12033
# [400]	train-logloss:0.11297
# [450]	train-logloss:0.10431
# [500]	train-logloss:0.09842
# [550]	train-logloss:0.09299
# [600]	train-logloss:0.08888
# [650]	train-logloss:0.08411
# [700]	train-logloss:0.08092
# [750]	train-logloss:0.07710
           Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/base.py:245, in ScriptDirectory._catch_revision_errors(self, ancestor, multiple_heads, start, end, resolution)
#     244 try:
# --> 245     yield
#     246 except revision.RangeNotAncestorError as rna:
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/base.py:455, in ScriptDirectory._upgrade_revs(self, destination, current_rev)
#     448 revs = self.iterate_revisions(
#     449     destination, current_rev, implicit_base=True
#     450 )
#     451 return [
#     452     migration.MigrationStep.upgrade_from_script(
#     453         self.revision_map, script
#     454     )
# --> 455     for script in reversed(list(revs))
#     456 ]
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/revision.py:800, in RevisionMap.iterate_revisions(self, upper, lower, implicit_base, inclusive, assert_relative_length, select_for_downgrade)
#     798     fn = self._collect_upgrade_revisions
# --> 800 revisions, heads = fn(
#     801     upper,
#     802     lower,
#     803     inclusive=inclusive,
#     804     implicit_base=implicit_base,
#     805     assert_relative_length=assert_relative_length,
#     806 )
#     808 for node in self._topological_sort(revisions, heads):
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/revision.py:1453, in RevisionMap._collect_upgrade_revisions(self, upper, lower, inclusive, implicit_base, assert_relative_length)
#    1447 required_node_set = set(
#    1448     self._get_ancestor_nodes(
#    1449         targets, check=True, include_dependencies=True
#    1450     )
#    1451 ).union(targets)
# -> 1453 current_revisions = self.get_revisions(lower)
#    1454 if not implicit_base and any(
#    1455     rev not in required_node_set
#    1456     for rev in current_revisions
#    1457     if rev is not None
#    1458 ):
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/revision.py:530, in RevisionMap.get_revisions(self, id_)
#     529 if isinstance(id_, (list, tuple, set, frozenset)):
# --> 530     return sum([self.get_revisions(id_elem) for id_elem in id_], ())
#     531 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/revision.py:530, in <listcomp>(.0)
#     529 if isinstance(id_, (list, tuple, set, frozenset)):
# --> 530     return sum([self.get_revisions(id_elem) for id_elem in id_], ())
#     531 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/revision.py:553, in RevisionMap.get_revisions(self, id_)
#     552         pass
# --> 553 return tuple(
#     554     self._revision_for_ident(rev_id, branch_label)
#     555     for rev_id in resolved_id
#     556 )
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/revision.py:554, in <genexpr>(.0)
#     552         pass
#     553 return tuple(
# --> 554     self._revision_for_ident(rev_id, branch_label)
#     555     for rev_id in resolved_id
#     556 )
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/revision.py:625, in RevisionMap._revision_for_ident(self, resolved_id, check_branch)
#     624 if not revs:
# --> 625     raise ResolutionError(
#     626         "No such revision or branch '%s'%s"
#     627         % (
#     628             resolved_id,
#     629             (
#     630                 "; please ensure at least four characters are "
#     631                 "present for partial revision identifier matches"
#     632                 if len(resolved_id) < 4
#     633                 else ""
#     634             ),
#     635         ),
#     636         resolved_id,
#     637     )
#     638 elif len(revs) > 1:
#
# ResolutionError: No such revision or branch '5b0e9adcef9c'
#
# The above exception was the direct cause of the following exception:
#
# CommandError                              Traceback (most recent call last)
# Cell In[3], line 2
#       1 MLFLOW_TRACKING_URI = "sqlite:///../../databases/mlflow.db"
# ----> 2 client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/client.py:86, in MlflowClient.__init__(self, tracking_uri, registry_uri)
#      84 final_tracking_uri = utils._resolve_tracking_uri(tracking_uri)
#      85 self._registry_uri = registry_utils._resolve_registry_uri(registry_uri, tracking_uri)
# ---> 86 self._tracking_client = TrackingServiceClient(final_tracking_uri)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py:52, in TrackingServiceClient.__init__(self, tracking_uri)
#      47 self.tracking_uri = tracking_uri
#      48 # NB: Fetch the tracking store (`self.store`) upon client initialization to ensure that
#      49 # the tracking URI is valid and the store can be properly resolved. We define `store` as a
#      50 # property method to ensure that the client is serializable, even if the store is not
#      51 # self.store  # pylint: disable=pointless-statement
# ---> 52 self.store
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py:56, in TrackingServiceClient.store(self)
#      54 @property
#      55 def store(self):
# ---> 56     return utils._get_store(self.tracking_uri)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/utils.py:216, in _get_store(store_uri, artifact_uri)
#     215 def _get_store(store_uri=None, artifact_uri=None):
# --> 216     return _tracking_store_registry.get_store(store_uri, artifact_uri)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/registry.py:39, in TrackingStoreRegistry.get_store(self, store_uri, artifact_uri)
#      36 from mlflow.tracking._tracking_service import utils
#      38 resolved_store_uri = utils._resolve_tracking_uri(store_uri)
# ---> 39 return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/registry.py:49, in TrackingStoreRegistry._get_store_with_resolved_uri(self, resolved_store_uri, artifact_uri)
#      43 """
#      44 Retrieve the store associated with a resolved (non-None) store URI and an artifact URI.
#      45 Caching is done on resolved URIs because the meaning of an unresolved (None) URI may change
#      46 depending on external configuration, such as environment variables
#      47 """
#      48 builder = self.get_store_builder(resolved_store_uri)
# ---> 49 return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/utils.py:138, in _get_sqlalchemy_store(store_uri, artifact_uri)
#     136 if artifact_uri is None:
#     137     artifact_uri = DEFAULT_LOCAL_FILE_AND_ARTIFACT_PATH
# --> 138 return SqlAlchemyStore(store_uri, artifact_uri)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/tracking/sqlalchemy_store.py:156, in SqlAlchemyStore.__init__(self, db_uri, default_artifact_root)
#     152 # On a completely fresh MLflow installation against an empty database (verify database
#     153 # emptiness by checking that 'experiments' etc aren't in the list of table names), run all
#     154 # DB migrations
#     155 if not mlflow.store.db.utils._all_tables_exist(self.engine):
# --> 156     mlflow.store.db.utils._initialize_tables(self.engine)
#     157 SessionMaker = sqlalchemy.orm.sessionmaker(bind=self.engine)
#     158 self.ManagedSessionMaker = mlflow.store.db.utils._get_managed_session_maker(
#     159     SessionMaker, self.db_type
#     160 )
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/db/utils.py:92, in _initialize_tables(engine)
#      90 _logger.info("Creating initial MLflow database tables...")
#      91 InitialBase.metadata.create_all(engine)
# ---> 92 _upgrade_db(engine)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/db/utils.py:215, in _upgrade_db(engine)
#     213 with engine.begin() as connection:
#     214     config.attributes["connection"] = connection
# --> 215     command.upgrade(config, "heads")
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/command.py:398, in upgrade(config, revision, sql, tag)
#     387     return script._upgrade_revs(revision, rev)
#     389 with EnvironmentContext(
#     390     config,
#     391     script,
#    (...)
#     396     tag=tag,
#     397 ):
# --> 398     script.run_env()
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/base.py:579, in ScriptDirectory.run_env(self)
#     570 def run_env(self) -> None:
#     571     """Run the script environment.
#     572
#     573     This basically runs the ``env.py`` script present
#    (...)
#     577
#     578     """
# --> 579     util.load_python_file(self.dir, "env.py")
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/util/pyfiles.py:93, in load_python_file(dir_, filename)
#      91 if ext == ".py":
#      92     if os.path.exists(path):
# ---> 93         module = load_module_py(module_id, path)
#      94     else:
#      95         pyc_path = pyc_file_from_path(path)
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/util/pyfiles.py:109, in load_module_py(module_id, path)
#     107 assert spec
#     108 module = importlib.util.module_from_spec(spec)
# --> 109 spec.loader.exec_module(module)  # type: ignore
#     110 return module
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/db_migrations/env.py:86
#      84     run_migrations_offline()
#      85 else:
# ---> 86     run_migrations_online()
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/db_migrations/env.py:80, in run_migrations_online()
#      75 context.configure(
#      76     connection=connection, target_metadata=target_metadata, render_as_batch=True
#      77 )
#      79 with context.begin_transaction():
# ---> 80     context.run_migrations()
#
# File <string>:8, in run_migrations(*args, **kw)
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/runtime/environment.py:938, in EnvironmentContext.run_migrations(self, **kw)
#     936 assert self._migration_context is not None
#     937 with Operations.context(self._migration_context):
# --> 938     self.get_context().run_migrations(**kw)
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/runtime/migration.py:612, in MigrationContext.run_migrations(self, **kw)
#     609 head_maintainer = HeadMaintainer(self, heads)
#     611 assert self._migrations_fn is not None
# --> 612 for step in self._migrations_fn(heads, self):
#     613     with self.begin_transaction(_per_migration=True):
#     614         if self.as_sql and not head_maintainer.heads:
#     615             # for offline mode, include a CREATE TABLE from
#     616             # the base
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/command.py:387, in upgrade.<locals>.upgrade(rev, context)
#     386 def upgrade(rev, context):
# --> 387     return script._upgrade_revs(revision, rev)
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/base.py:443, in ScriptDirectory._upgrade_revs(self, destination, current_rev)
#     440 def _upgrade_revs(
#     441     self, destination: str, current_rev: str
#     442 ) -> List[RevisionStep]:
# --> 443     with self._catch_revision_errors(
#     444         ancestor="Destination %(end)s is not a valid upgrade "
#     445         "target from current head(s)",
#     446         end=destination,
#     447     ):
#     448         revs = self.iterate_revisions(
#     449             destination, current_rev, implicit_base=True
#     450         )
#     451         return [
#     452             migration.MigrationStep.upgrade_from_script(
#     453                 self.revision_map, script
#     454             )
#     455             for script in reversed(list(revs))
#     456         ]
#
# File ~/anaconda3/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     153     value = typ()
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#     160     return exc is not value
#
# File ~/anaconda3/lib/python3.11/site-packages/alembic/script/base.py:277, in ScriptDirectory._catch_revision_errors(self, ancestor, multiple_heads, start, end, resolution)
#     273     if resolution is None:
#     274         resolution = "Can't locate revision identified by '%s'" % (
#     275             re.argument
#     276         )
# --> 277     raise util.CommandError(resolution) from re
#     278 except revision.RevisionError as err:
#     279     raise util.CommandError(err.args[0]) from err
#
# CommandError: Can't locate revision identified by '5b0e9adcef9c'

# %%
runs = client.search_runs(
    experiment_ids='1',
    filter_string="metrics.f1_score >0.595",
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=5,
    order_by=["metrics.f1_score ASC"]
)

# %%
for run in runs:
    print(f"run id: {run.info.run_id}, F1 Score: {run.data.metrics['f1_score']:.4f}")

# %%
for run in runs:
    run_id = run.info.run_id
    model_uri = f"runs:/{run_id}/model"
    mlflow.register_model(model_uri=model_uri, name="Custormer-churn-models")

# %%
model_name = "Custormer-churn-models"
latest_versions = client.get_latest_versions(name=model_name)
for version in latest_versions:
    print(f"version: {version.version}, stage: {version.current_stage}")
# Out:
# version: 5, stage: None

# %%
model_version = 5
new_stage = "Staging"
client.transition_model_version_stage(
    name=model_name,
    version=model_version,
    stage=new_stage,
    archive_existing_versions=False
)
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1692104278613, current_stage='Staging', description=None, last_updated_timestamp=1692104474582, name='Custormer-churn-models', run_id='eb579b6644f94306b371e1dbfb884a44', run_link=None, source='/home/godwin/Documents/Workflow/Churn-Prediction-in-a-Telecom-Company/mlruns/1/eb579b6644f94306b371e1dbfb884a44/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=5>

# %%
from datetime import datetime


new_stage = 'Staging'
version = 5
date = datetime.today().date() 

client.update_model_version(
    name=model_name,
    version=version,
    description=f"The model version {version}  was transitioned to {new_stage} on {date}"
)
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1692104278613, current_stage='Staging', description='The model version 5  was transitioned to Staging on 2023-08-15', last_updated_timestamp=1692104613905, name='Custormer-churn-models', run_id='eb579b6644f94306b371e1dbfb884a44', run_link=None, source='/home/godwin/Documents/Workflow/Churn-Prediction-in-a-Telecom-Company/mlruns/1/eb579b6644f94306b371e1dbfb884a44/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=5>
